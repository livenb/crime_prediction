# %%
import matplotlib
matplotlib.use('Agg')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist, pdist
from sklearn.decomposition import NMF
import seaborn as sns



def elbow_silhouette_kmeans(X, year=None):
    dists = []
    s_scores = []
    for k in xrange(2, 20):
        print year, k
        model = KMeans(n_clusters=k)
        model.fit(X)
        centroids = model.cluster_centers_
        labels = model.labels_
        dist = cdist(X, centroids)
        dists.append(dist.min(axis=1).sum())
#         s_scores.append(silhouette_score(X, labels, metric='euclidean'))
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.plot(xrange(2, 20), dists, 'b*-')
    ax1.grid(True)
    ax1.set_xlabel('Number of clusters')
    ax1.set_ylabel('sum of squares')
    ax1.set_title('Elbow for KMeans clustering - {}'.format(year))
#     ax2 = fig.add_subplot(122)
#     ax2.plot(xrange(2, 20), s_scores)
#     ax2.grid(True)
#     ax2.set_title('Choose K based on Silhouette Score')
#     ax2.set_xlabel('Number of Cluster')
#     ax2.set_ylabel('Silhouette Score')
#     plt.show()
    plt.savefig('{}_kmeans.png'.format(year))


def kmeans_by_year(X, yrs, years):
    for yr in years:
        X_yr = X[yrs == yr]
        elbow_silhouette_kmeans(X_yr, yr)
    # plt.show()
    print 'kmeans done!'


def build_nmf(X, yrs, years):
    Ws = []
    Hs = []
    for yr in years:
        print yr, 'nmf'
        X_yr = X[yrs == yr]
        nmfModel = NMF(n_components=10)
        W = nmfModel.fit_transform(X_yr)
        H = nmfModel.components_
        Ws.append(W)
        Hs.append(H)
        sns.heatmap(W)
        plt.title('W heatmap - {}'.format(yr))
        plt.savefig('{}_nmf_heatmap.png'.format(yr))
    return Ws, Hs


def plot_cluster():
    plt.figure()
    plt.show()

# %%
sfdata = pd.read_csv('data/sfpd_clean.csv')
dropLst = ['Descript', 'PdDistrict', 'Address', 'Year', 'X']
sfdata['nnX'] = -sfdata['X'] 
X = sfdata.drop(dropLst, axis=1).values
yrs = sfdata['Year'].values
years = sorted(sfdata['Year'].unique())
kmeans_by_year(X, yrs, years)
# Out:
# 2003 2
# 2003 3
# 2003 4
# 2003 5
# 2003 6
# 2003 7
# 2003 8
# 2003 9
# 2003 10
# 2003 11
# 2003 12
# 2003 13
# 2003 14
# 2003 15
# 2003 16
# 2003 17
# 2003 18
# 2003 19
# 2004 2
# 2004 3
# 2004 4
# 2004 5
# 2004 6
# 2004 7
# 2004 8
# 2004 9
# 2004 10
# 2004 11
# 2004 12
# 2004 13
# 2004 14
# 2004 15
# 2004 16
# 2004 17
# 2004 18
# 2004 19
# 2005 2
# 2005 3
# 2005 4
# 2005 5
# 2005 6
# 2005 7
# 2005 8
# 2005 9
# 2005 10
# 2005 11
# 2005 12
# 2005 13
# 2005 14
# 2005 15
# 2005 16
# 2005 17
# 2005 18
# 2005 19
# 2006 2
# 2006 3
# 2006 4
# 2006 5
# 2006 6
# 2006 7
# 2006 8
# 2006 9
# 2006 10
# 2006 11
# 2006 12
# 2006 13
# 2006 14
# 2006 15
# 2006 16
# 2006 17
# 2006 18
# 2006 19
# 2007 2
# 2007 3
# 2007 4
# 2007 5
# 2007 6
# 2007 7
# 2007 8
# 2007 9
# 2007 10
# 2007 11
# 2007 12
# 2007 13
# 2007 14
# 2007 15
# 2007 16
# 2007 17
# 2007 18
# 2007 19
# 2008 2
# 2008 3
# 2008 4
# 2008 5
# 2008 6
# 2008 7
# 2008 8
# 2008 9
# 2008 10
# 2008 11
# 2008 12
# 2008 13
# 2008 14
# 2008 15
# 2008 16
# 2008 17
# 2008 18
# 2008 19
# 2009 2
# 2009 3
# 2009 4
# 2009 5
# 2009 6
# 2009 7
# 2009 8
# 2009 9
# 2009 10
# 2009 11
# 2009 12
# 2009 13
# 2009 14
# 2009 15
# 2009 16
# 2009 17
# 2009 18
# 2009 19
# 2010 2
# 2010 3
# 2010 4
# 2010 5
# 2010 6
# 2010 7
# 2010 8
# 2010 9
# 2010 10
# 2010 11
# 2010 12
# 2010 13
# 2010 14
# 2010 15
# 2010 16
# 2010 17
# 2010 18
# 2010 19
# 2011 2
# 2011 3
# 2011 4
# 2011 5
# 2011 6
# 2011 7
# 2011 8
# 2011 9
# 2011 10
# 2011 11
# 2011 12
# 2011 13
# 2011 14
# 2011 15
# 2011 16
# 2011 17
# 2011 18
# 2011 19
# 2012 2
# 2012 3
# 2012 4
# 2012 5
# 2012 6
# 2012 7
# 2012 8
# 2012 9
# 2012 10
# 2012 11
# 2012 12
# 2012 13
# 2012 14
# 2012 15
# 2012 16
# 2012 17
# 2012 18
# 2012 19
# 2013 2
# 2013 3
# 2013 4
# 2013 5
# 2013 6
# 2013 7
# 2013 8
# 2013 9
# 2013 10
# 2013 11
# 2013 12
# 2013 13
# 2013 14
# 2013 15
# 2013 16
# 2013 17
# 2013 18
# 2013 19
# 2014 2
# 2014 3
# 2014 4
# 2014 5
# 2014 6
# 2014 7
# 2014 8
# 2014 9
# 2014 10
# 2014 11
# 2014 12
# 2014 13
# 2014 14
# 2014 15
# 2014 16
# 2014 17
# 2014 18
# 2014 19
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2015 13
# 2015 14
# 2015 15
# 2015 16
# 2015 17
# 2015 18
# 2015 19
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12
# 2016 13
# 2016 14
# 2016 15
# 2016 16
# 2016 17
# 2016 18
# 2016 19
# kmeans done!

# %%
plt.show()

# %%
build_nmf(X, yrs, years)
# Out:
# ---------------------------------------------------------------
# KeyboardInterrupt             Traceback (most recent call last)
# <ipython-input-9-67b6d6bb5683> in <module>()
# ----> 1 build_nmf(X, yrs, years)
#
# <ipython-input-8-c061253a360a> in build_nmf(X, yrs, years)
#      57         Ws.append(W)
#      58         Hs.append(H)
# ---> 59         sns.heatmap(W)
#      60         plt.title('W heatmap - {}'.format(yr))
#      61         plt.savefig('{}_nmf_heatmap.png'.format(yr))
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/seaborn/matrix.pyc in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, ax, xticklabels, yticklabels, mask, **kwargs)
#     461     if square:
#     462         ax.set_aspect("equal")
# --> 463     plotter.plot(ax, cbar_ax, kwargs)
#     464     return ax
#     465
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/seaborn/matrix.pyc in plot(self, ax, cax, kws)
#     236
#     237         # Possibly rotate them if they overlap
# --> 238         plt.draw()
#     239         if axis_ticklabels_overlap(xtl):
#     240             plt.setp(xtl, rotation="vertical")
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in draw()
#     680         fig.canvas.draw_idle()
#     681     """
# --> 682     get_current_fig_manager().canvas.draw_idle()
#     683
#     684
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in draw_idle(self, *args, **kwargs)
#    2024         if not self._is_idle_drawing:
#    2025             with self._idle_draw_cntx():
# -> 2026                 self.draw(*args, **kwargs)
#    2027
#    2028     def draw_cursor(self, event):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer)
#     250
#     251         if self.label1On:
# --> 252             self.label1.draw(renderer)
#     253         if self.label2On:
#     254             self.label2.draw(renderer)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in draw(self, renderer)
#     747
#     748         with _wrap_text(self) as textobj:
# --> 749             bbox, info, descent = textobj._get_layout(renderer)
#     750             trans = textobj.get_transform()
#     751
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     359                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     360                                                         self._fontproperties,
# --> 361                                                         ismath=ismath)
#     362             else:
#     363                 w, h, d = 0, 0, 0
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in get_text_width_height_descent(self, s, prop, ismath)
#     235             return width, height, descent
#     236
# --> 237         flags = get_hinting_flag()
#     238         font = self._get_agg_font(prop)
#     239         font.set_text(s, 0.0, flags=flags)  # the width and height of unrotated string
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in get_hinting_flag()
#      60         'none': LOAD_NO_HINTING
#      61         }
# ---> 62     return mapping[rcParams['text.hinting']]
#      63
#      64
#
# KeyboardInterrupt:
